# %%
from sklearn.impute import SimpleImputer
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression

# %%
def default_Y_generator(df):
    # 生成违约的Y
    default_df = df[df['逾期金额'] > 0]
    print(f'违约数据集大小：{default_df.shape}')
    df['存在逾期贷款'] = df.groupby('Stkcd')['逾期金额'].shift(-1).fillna(0).apply(lambda x: 1 if x > 0 else 0)
    print(f'生成违约Y：{df["存在逾期贷款"].value_counts()}')
    return df

def isnull_filter(df, threshold):
    # 缺失值筛选
    # 计算每列缺失值的比例
    missing_ratio = df.isnull().mean()
    # 找出需要保留的列（缺失比例小于等于阈值）
    columns_to_keep = missing_ratio[missing_ratio <= threshold].index
    # 删去了哪些列
    columns_to_drop = missing_ratio[missing_ratio > threshold].index
    print(f'根据缺失比例，删去的列：{columns_to_drop}')
    # 返回筛选后的 DataFrame
    df = df[columns_to_keep]
    print(f'缺失值筛选后数据集大小：{df.shape}')
    return df

def encode_generator(df):
    df = df.copy()
    label_encoders = {}
    encoded_columns = []
    for col in df.columns:
        if df[col].dtype == 'object':
            try:
                df[col].astype(float)
            except ValueError:
                print(f'编码 {col} 列...')
                le = LabelEncoder()
                df[col] = le.fit_transform(df[col])
                label_encoders[col] = le
                encoded_columns.append(col)
    print(f'被编码的列名：{encoded_columns}')
    return df, label_encoders, encoded_columns

def correlation_filter(df, threshold=0.9):
    df = df.copy()
    corr_matrix = df.corr().abs()
    high_corr_pairs = []
    to_drop = set()
    for i in range(len(corr_matrix.columns)):
        for j in range(i + 1, len(corr_matrix.columns)):
            col1 = corr_matrix.columns[i]
            col2 = corr_matrix.columns[j]
            if corr_matrix.iloc[i, j] > threshold:
                high_corr_pairs.append((col1, col2))
                to_drop.add(col2)
    df_filtered = df.drop(columns=list(to_drop))
    print(f'高相关性的列对：{high_corr_pairs}')
    print(f'被删除的列名：{list(to_drop)}')
    print(f'筛选后的 DataFrame 大小：{df_filtered.shape}')
    return df_filtered, high_corr_pairs, list(to_drop)

# %%
def train_and_evaluate_logistic_regression_with_tuning(df, target_column, test_size=0.2, random_state=42, C=[1.0], penalty=['l2']):
    X = df.drop(columns=[target_column])
    y = df[target_column]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    
    pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler()),
        ('log_reg', LogisticRegression(solver='liblinear'))  # 使用逻辑回归分类器
    ])
    
    param_grid = {
        'log_reg__C': C,
        'log_reg__penalty': penalty
    }
    
    grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=3, n_jobs=-1, scoring='accuracy', error_score='raise')
    
    try:
        grid_search.fit(X_train, y_train)
        best_params = grid_search.best_params_
        best_model = grid_search.best_estimator_
        y_pred_best = best_model.predict(X_test)
        best_accuracy = accuracy_score(y_test, y_pred_best)
        best_report = classification_report(y_test, y_pred_best)
        return best_accuracy, best_report, best_params
    except Exception as e:
        print(f"训练过程中发生错误: {e}")
        return None, None, None
def main():
    df = pd.read_csv('merged_data_final.csv')
    print(f'原始数据集大小：{df.shape}')
    print(df.head(5))
    df = default_Y_generator(df)
    threshold = 0.3
    df = isnull_filter(df, threshold)
    encoded_df, label_encoders, encoded_columns = encode_generator(df)
    print('编码后的 DataFrame:')
    print(encoded_df.head(5))
    df_filtered, high_corr_pairs, to_drop = correlation_filter(encoded_df)
    print('筛选后的 DataFrame:')
    print(df_filtered.head(5))
    result = train_and_evaluate_logistic_regression_with_tuning(
        df_filtered, 
        target_column='存在逾期贷款', 
        test_size=0.2, 
        random_state=42, 
        C=[1.0], 
        penalty=['l2']
    )
    
    if result[0] is not None:
        print(f"最佳准确率: {result[0]:.4f}")
        print(f"最佳超参数: {result[2]}")
        print("最佳分类报告:")
        print(result[1])
    else:
        print("模型训练失败，请检查错误信息。") 
if __name__ == '__main__':
    main()
# Out:
# 原始数据集大小：(104851, 155)
#    Stkcd ShortName_FS_Comins      Accper Typrep         营业总收入          营业收入  \
# 0      2                深万科A  2000-12-31      A  3.783669e+09  3.783669e+09
# 1      2                深万科A  2001-06-30      A  2.432696e+09  2.432696e+09
# 2      2                深万科A  2001-12-31      A  4.455065e+09  4.455065e+09
# 3      2                 万科A  2002-06-30      A  1.501989e+09  1.501989e+09
# 4      2                 万科A  2002-12-31      A  4.574360e+09  4.574360e+09
#
#    利息支出         营业总成本          营业成本  其中：利息费用(财务费用)  ...          其他借款  \
# 0   NaN  3.436558e+09  2.839928e+09            NaN  ...  6.000000e+08
# 1   NaN  2.208490e+09  1.831923e+09            NaN  ...  1.131000e+09
# 2   NaN  4.157431e+09  3.434440e+09            NaN  ...           NaN
# 3   NaN  1.325194e+09  1.072018e+09            NaN  ...           NaN
# 4   NaN  4.062517e+09  3.472886e+09            NaN  ...           NaN
#
#    资产负债率_y  信用借款比例  抵押借款比例  担保借款比例  逾期金额  展期金额  贷款偿还率        主营业务收入  每股现金流
# 0      0.0     NaN  7.1207  7.1207   NaN   NaN    NaN  3.783669e+09    0.0
# 1      0.0     NaN  3.9082  3.9082   NaN   NaN    NaN  2.432696e+09    0.0
# 2      0.0   100.0     NaN     NaN   NaN   NaN    NaN  4.455065e+09    0.0
# 3      0.0   100.0     NaN     NaN   NaN   NaN    NaN  1.501989e+09    0.0
# 4      0.0   100.0     NaN     NaN   NaN   NaN    NaN  4.574360e+09    0.0
#
# [5 rows x 155 columns]
# 违约数据集大小：(5624, 155)
# 生成违约Y：0    99433
# 1     5418
# Name: 存在逾期贷款, dtype: int64
# 根据缺失比例，删去的列：Index(['利息支出', '其中：利息费用(财务费用)', '持续经营净利润', '终止经营净利润', '综合收益增长率',
#        '息税折旧前利润/利息费用', '板块', '公司名称', '行业名称', '上市日期', '成立日期', '注册资本', '注册地址',
#        '审计意见', '执行人数', '财务报告', '其中：质押借款', '保证借款', '信用借款', '抵押借款', '票据贴现',
#        '其他借款', '信用借款比例', '抵押借款比例', '逾期金额', '展期金额', '贷款偿还率', '主营业务收入'],
#       dtype='object')
# 缺失值筛选后数据集大小：(104851, 128)
# 编码 ShortName_FS_Comins 列...
# 编码 Accper 列...
# 编码 Typrep 列...
# 编码 统计截止日期 列...
# 被编码的列名：['ShortName_FS_Comins', 'Accper', 'Typrep', '统计截止日期']
# 编码后的 DataFrame:
#    Stkcd  ShortName_FS_Comins  Accper  Typrep         营业总收入          营业收入  \
# 0      2                 6926       0       0  3.783669e+09  3.783669e+09
# 1      2                 6926       1       0  2.432696e+09  2.432696e+09
# 2      2                 6926       2       0  4.455065e+09  4.455065e+09
# 3      2                 2443       3       0  1.501989e+09  1.501989e+09
# 4      2                 2443       4       0  4.574360e+09  4.574360e+09
#
#           营业总成本          营业成本          营业利润           净利润  ...        短期借款_y  \
# 0  3.436558e+09  2.839928e+09  3.688866e+08  3.111773e+08  ...  5.660000e+08
# 1  2.208490e+09  1.831923e+09  2.258725e+08  1.780492e+08  ...  9.860000e+08
# 2  4.157431e+09  3.434440e+09  4.948748e+08  3.819693e+08  ...  1.353000e+09
# 3  1.325194e+09  1.072018e+09  1.748535e+08  1.421569e+08  ...  1.118000e+09
# 4  4.062517e+09  3.472886e+09  5.227655e+08  3.980483e+08  ...  4.600000e+08
#
#    短期借款占总资产比例       长期借款_y  一年内到期的长期借款  长期借款占总资产比例( %)          借款总额  资产负债率_y  \
# 0     10.0671   80000000.0         0.0          1.4229  6.460000e+08      0.0
# 1     16.2559  191000000.0         0.0          3.1490  1.177000e+09      0.0
# 2     20.8703  261000000.0         0.0          4.0260  1.614000e+09      0.0
# 3     13.5950  160000000.0         0.0          1.9456  1.278000e+09      0.0
# 4      5.5990  160000000.0         0.0          1.9475  6.200000e+08      0.0
#
#    担保借款比例  每股现金流  存在逾期贷款
# 0  7.1207    0.0       0
# 1  3.9082    0.0       0
# 2     NaN    0.0       0
# 3     NaN    0.0       0
# 4     NaN    0.0       0
#
# [5 rows x 128 columns]
# 高相关性的列对：[('Stkcd', '证券代码'), ('Accper', '统计截止日期'), ('营业总收入', '营业收入'), ('营业总收入', '营业总成本'), ('营业总收入', '营业成本'), ('营业收入', '营业总成本'), ('营业收入', '营业成本'), ('营业总成本', '营业成本'), ('营业利润', '净利润'), ('营业利润', '息税前利润（EBIT）'), ('营业利润', '息税前利润（EBIT）TTM'), ('营业利润', '息税折旧摊销前收入（EBITDA）'), ('净利润', '息税前利润（EBIT）'), ('净利润', '息税前利润（EBIT）TTM'), ('净利润', '息税折旧摊销前收入（EBITDA）'), ('流动比率', '速动比率'), ('流动比率', '保守速动比率'), ('速动比率', '保守速动比率'), ('利息保障倍数A', '利息保障倍数B'), ('经营活动产生的现金流量净额／流动负债', '经营净现金流量/负债合计'), ('资产负债率_x', '有形资产负债率'), ('资产负债率_x', '有形资产带息债务比'), ('资产负债率_x', '带息债务率'), ('资产负债率_x', '短期借款占总资产比例'), ('长期借款与总资产比', '长期借款占总资产比例( %)'), ('有形资产负债率', '有形资产带息债务比'), ('有形资产负债率', '带息债务率'), ('有形资产负债率', '短期借款占总资产比例'), ('有形资产带息债务比', '带息债务率'), ('有形资产带息债务比', '短期借款占总资产比例'), ('经营活动产生的现金流量净额／负债合计', '经营净现金流量/负债合计'), ('应收账款周转率B', '应收账款周转率C'), ('应收账款周转率B', '应收账款周转率D'), ('应收账款周转率B', '应收账款周转率TTM'), ('应收账款周转率C', '应收账款周转率D'), ('应收账款周转率C', '应收账款周转率TTM'), ('应收账款周转率D', '应收账款周转率TTM'), ('存货周转率A', '存货周转率B'), ('存货周转率A', '存货周转率C'), ('存货周转率A', '存货周转率D'), ('存货周转率A', '存货周转率TTM'), ('存货周转率B', '存货周转率C'), ('存货周转率B', '存货周转率D'), ('存货周转率B', '存货周转率TTM'), ('存货周转率C', '存货周转率D'), ('存货周转率C', '存货周转率TTM'), ('存货周转率D', '存货周转率TTM'), ('应付账款周转率C', '应付账款周转率D'), ('应付账款周转率D', '应付账款周转率TTM'), ('营运资金(资本)周转率B', '营运资金(资本)周转率C'), ('营运资金(资本)周转率B', '营运资金(资本)周转率D'), ('营运资金(资本)周转率C', '营运资金(资本)周转率D'), ('营运资金(资本)周转率C', '营运资金(资本)周转率TTM'), ('流动资产周转率A', '流动资产周转率B'), ('流动资产周转率A', '流动资产周转率C'), ('流动资产周转率B', '流动资产周转率C'), ('流动资产周转率D', '流动资产周转率TTM'), ('总资产周转率A', '总资产周转率B'), ('总资产周转率A', '总资产周转率C'), ('总资产周转率B', '总资产周转率C'), ('总资产周转率D', '总资产周转率TTM'), ('资产报酬率A', '总资产净利润率(ROA)A'), ('资产报酬率B', '资产报酬率C'), ('资产报酬率B', '总资产净利润率(ROA)B'), ('资产报酬率B', '总资产净利润率(ROA)C'), ('资产报酬率C', '总资产净利润率(ROA)B'), ('资产报酬率C', '总资产净利润率(ROA)C'), ('资产报酬率TTM', '总资产净利润率(ROA)TTM'), ('总资产净利润率(ROA)B', '总资产净利润率(ROA)C'), ('净资产收益率（ROE）B', '净资产收益率（ROE）C'), ('净资产收益率（ROE）B', '可持续增长率3'), ('净资产收益率（ROE）C', '可持续增长率3'), ('息税前利润（EBIT）', '息税前利润（EBIT）TTM'), ('息税前利润（EBIT）', '息税折旧摊销前收入（EBITDA）'), ('息税前利润（EBIT）TTM', '息税折旧摊销前收入（EBITDA）TTM'), ('息税折旧摊销前收入（EBITDA）', '息税折旧摊销前收入（EBITDA）TTM'), ('息税折旧摊销前收入（EBITDA）', '所有者权益合计'), ('息税折旧摊销前收入（EBITDA）TTM', '所有者权益合计'), ('营业利润率', '营业利润率TTM'), ('营业利润率', '营业净利率'), ('营业利润率', '营业净利率TTM'), ('营业利润率TTM', '营业净利率'), ('营业利润率TTM', '营业净利率TTM'), ('营业净利率', '营业净利率TTM'), ('净利润增长率B', '净利润增长率C'), ('营业收入增长率B', '营业收入增长率C'), ('可持续增长率', '可持续增长率2'), ('资产总计', '负债合计'), ('资产总计', '总资产'), ('短期借款_x', '短期借款_y'), ('一年内到期的非流动负债', '一年内到期的长期借款'), ('长期借款_x', '非流动负债合计'), ('长期借款_x', '带息债务'), ('长期借款_x', '长期借款_y'), ('长期借款_x', '借款总额'), ('长期负债合计', '非流动负债合计'), ('非流动负债合计', '带息债务'), ('非流动负债合计', '长期借款_y'), ('非流动负债合计', '借款总额'), ('负债合计', '总资产'), ('带息债务', '长期借款_y'), ('带息债务', '借款总额'), ('带息债务率', '短期借款占总资产比例'), ('长期借款_y', '借款总额')]
# 被删除的列名：['总资产净利润率(ROA)TTM', '总资产净利润率(ROA)C', '营业利润率TTM', '流动资产周转率TTM', '可持续增长率3', '存货周转率TTM', '证券代码', '所有者权益合计', '流动资产周转率C', '应收账款周转率C', '可持续增长率2', '有形资产负债率', '保守速动比率', '营运资金(资本)周转率D', '应付账款周转率D', '总资产周转率TTM', '营业收入', '流动资产周转率B', '带息债务', '长期借款占总资产比例( %)', '净利润', '短期借款占总资产比例', '存货周转率C', '短期借款_y', '总资产周转率B', '借款总额', '长期借款_y', '存货周转率B', '息税折旧摊销前收入（EBITDA）TTM', '一年内到期的长期借款', '速动比率', '营业成本', '非流动负债合计', '总资产净利润率(ROA)A', '有形资产带息债务比', '营运资金(资本)周转率TTM', '带息债务率', '总资产净利润率(ROA)B', '应收账款周转率TTM', '总资产周转率C', '营业净利率TTM', '利息保障倍数B', '应付账款周转率TTM', '营运资金(资本)周转率C', '资产报酬率C', '经营净现金流量/负债合计', '净利润增长率C', '总资产', '净资产收益率（ROE）C', '统计截止日期', '营业净利率', '负债合计', '营业收入增长率C', '息税前利润（EBIT）', '营业总成本', '息税前利润（EBIT）TTM', '存货周转率D', '应收账款周转率D', '息税折旧摊销前收入（EBITDA）']
# 筛选后的 DataFrame 大小：(104851, 69)
# 筛选后的 DataFrame:
#    Stkcd  ShortName_FS_Comins  Accper  Typrep         营业总收入          营业利润  \
# 0      2                 6926       0       0  3.783669e+09  3.688866e+08
# 1      2                 6926       1       0  2.432696e+09  2.258725e+08
# 2      2                 6926       2       0  4.455065e+09  4.948748e+08
# 3      2                 2443       3       0  1.501989e+09  1.748535e+08
# 4      2                 2443       4       0  4.574360e+09  5.227655e+08
#
#        流动比率      现金比率     利息保障倍数A  经营活动产生的现金流量净额／流动负债  ...  筹资活动产生的现金流量净额  \
# 0  1.987036  0.393155  276.098682            0.033975  ...   1.734380e+08
# 1  2.019980  0.279204         NaN           -0.265289  ...   5.096891e+08
# 2  1.991119  0.264451         NaN           -0.395519  ...   7.859737e+08
# 3  2.386027  0.509549         NaN           -0.063773  ...   1.094869e+09
# 4  2.532806  0.388607         NaN            0.042167  ...   2.869236e+08
#
#    股东权益/负债合计  货币资金/短期债务  息税折旧前利润/带息债务       自由现金净流量  频率标识  资产负债率_y  担保借款比例  \
# 0   1.116330   1.759267      0.626149  2.301056e+07     4      0.0  7.1207
# 1   1.049595   0.773844      0.437430 -7.513681e+08     2      0.0  3.9082
# 2   0.931260   0.595256      0.417744 -1.234712e+09     4      0.0     NaN
# 3   0.659008   1.488275      0.473335 -2.422318e+08     2      0.0     NaN
# 4   0.715431   2.581316      0.930496  7.703608e+07     4      0.0     NaN
#
#    每股现金流  存在逾期贷款
# 0    0.0       0
# 1    0.0       0
# 2    0.0       0
# 3    0.0       0
# 4    0.0       0
#
# [5 rows x 69 columns]
# 最佳准确率: 0.9489
# 最佳超参数: {'log_reg__C': 1.0, 'log_reg__penalty': 'l2'}
# 最佳分类报告:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     19868
#            1       0.60      0.09      0.15      1103
#
#     accuracy                           0.95     20971
#    macro avg       0.78      0.54      0.56     20971
# weighted avg       0.93      0.95      0.93     20971
